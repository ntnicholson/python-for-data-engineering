# %% [markdown]
# ## What are modules?
# - Modules are Python scripts
# -- Files ending with `.py`
# --

# %%
import os

## Get current working directory
print(os.getcwd())
os.e
# Out:
# c:\Users\nicho\OneDrive\Documents\Projects\python-for-data-engineering

# %%
import string
## useful for validating user input
print(string.ascii_letters) 
print(string.digits)
print(string.punctuation)

# %% [markdown]
# ## Installing a Package
# - Terminal
# `python3 -m pip install <package_name>`

# %%
## packages
## pandas are popular
##python3 -m pip install pandas
import pandas as pd

sales = {"user_id": ["KM37", "PR15", "YU88"],
         "oder_value": [236.89, 6435.87, 8645.89]}

##use panda to change to tabular data - dataframe
sales_df = pd.DataFrame(sales)
print(sales_df)
# Out:
#   user_id  oder_value
# 0    KM37      236.89
# 1    PR15     6435.87
# 2    YU88     8645.89

# %%
##Reading in a excel file
maven_data = pd.read_excel("maven_ski_shop_data.xlsx")
print(maven_data.head()) ##first 5 rows
# Out:
#    Product_ID Product_Name  Price   Cost        Available Sizes  Euro Price
# 0       10001       Coffee   5.99   0.99                  250mL        5.27
# 1       10002       Beanie   9.99   4.29           Child, Adult        8.79
# 2       10003       Gloves  19.99   7.99           Child, Adult       17.59
# 3       10004   Sweatshirt  24.99  10.59  XS, S, M, L , XL, XXL       21.99
# 4       10005       Helmet  99.99  49.99           Child, Adult       87.99

# %%
def average(values):
    average_value = sum(values) / len(values)
    rounded_average = round(average_value, 2)
    return rounded_average
