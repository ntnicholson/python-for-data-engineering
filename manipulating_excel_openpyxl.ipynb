# %%
import openpyxl as xl

workbook = xl.load_workbook(filename='maven_ski_shop_data.xlsx')

# %%
workbook.sheetnames
workbook.active = 1
items = workbook["Item_Info"]
items['B1'].value
items.cell(row= 1, column=2).value
# Out:
# 'Product_Name'

# %%
items.max_column
items.max_row
