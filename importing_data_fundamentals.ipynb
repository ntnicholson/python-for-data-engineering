# %%
## Reading a text file
filename = '.txt'
file = open(file=filename, mode='r') # r is read only, 'w' to write
text = file.read()
file.close() 
## or use (with) to auto manage closing
with open(filename, 'r') as file:
    print(file.readline())

# %% [markdown]
# # Importing using Numpy
# ## Python standard for storing numerical data

# %%
import numpy as np
## not good with mixed data types in column
filename = '.txt'
data = np.loadtxt(filename, delimiter=',', dtype=str)
data

# %% [markdown]
# # Importing using Pandas

# %%
import pandas as pd

data = pd.read_csv('data_files/Heart_Disease_Prediction.csv')
# , sep='\t', comments='#', na_values=['Nothing']
print(data.head(5))
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %% [markdown]
# # Importing SQL using SQLAlchemy

# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

load_dotenv()
#
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
database_name = os.getenv('DB_NAME')
print(password)

DB_URL = f'mysql+mysqlconnector://{user}:{password}@{host}/{database_name}'
engine = create_engine(DB_URL) #'mysql+mysqlconnector://user:password@host/database_name'

#test connection
try:
    connection = engine.connect()
    print(engine.table_names())
except Exception as e:
    print(e)
# Out:
# (mysql.connector.errors.ProgrammingError) 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
import os
from dotenv import load_dotenv

print(os.getenv('DB_PASSWORD'))
